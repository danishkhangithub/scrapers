# %%
import pandas as pd

# %%
data = pd.read_csv('Stock_Screener_OTC_USA_Canada_Under10.csv')
data
# Out:
#      Symbol             Security Name                 Tier  Price  Change %  \
# 0      FRSB  FIRST RESOURCE BANK (PA)   OTCQX U.S. Premier  9.850   -0.0010
# 1      TCNB     TOWN CENTER BANK (IL)   OTCQX U.S. Premier  3.150       NaN
# 2      SLNG    STABILIS SOLUTIONS INC   OTCQX U.S. Premier  6.990    6.7176
# 3      KSHB       KUSHCO HOLDINGS INC   OTCQX U.S. Premier  1.215   -8.3019
# 4      CBBI           CBB BANCORP INC   OTCQX U.S. Premier  9.900   -0.2016
# ...     ...                       ...                  ...    ...       ...
# 3354   KNIT         KINETIC GROUP INC  Pink No Information  1.890       NaN
# 3355   FIGM        FUTURE INTL GRP CP  Pink No Information  8.000       NaN
# 3356  FWDEQ     FIELDWOOD ENERGY INC.  Pink No Information  0.003       NaN
# 3357   SMGE   SIGMATA ELECTRONICS INC  Pink No Information  0.000       NaN
# 3358   PTNL           PLANTATION CORP  Pink No Information  0.000       NaN
#
#           Vol      Sec Type Country         State  \
# ...

# %%
with open('output2.txt', 'w') as f:
    for text in data['Symbol'].tolist():
        f.write(text + '\n')
